# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from PIL import Image
from tqdm import tqdm_notebook
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
input_path = Path('/content/sample_data/Untitled Folder')
im_size = 320

# %%
image_files = list(input_path.glob('*.jpg'))

# %%
def read_file(fname):
    # Read image
    im = Image.open(fname)

    # Resize
    im.thumbnail((im_size, im_size))

    # Convert to numpy array
    im_array = np.asarray(im)

    # Get target
    target = int(fname.stem.split('_')[0])

    return im_array, target

# %%
images = []
targets = []

for image_file in tqdm_notebook(image_files):
    image, target = read_file(image_file)
    
    images.append(image)
    targets.append(target)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   after removing the cwd from sys.path.
# HBox(children=(FloatProgress(value=0.0, max=1152.0), HTML(value='')))

# %%
X = (np.array(images).astype(np.float32) / 127.5) - 1
y_cls = np.array(targets)

# %%
X.shape, y_cls.shape
# Out:
# ((1152, 240, 320, 3), (1152,))

# %%
i = 555
plt.imshow(np.uint8((X[i] + 1) * 127.5))
plt.title(str(y_cls[i]));

# %%
coins_ids = {
    5: 0,
    10: 1,
    25: 2,
    50: 3,
    100: 4
}

ids_coins = [5, 10, 25, 50, 100]

y = np.array([coins_ids[coin] for coin in y_cls])

# %%
X_train, X_valid, y_train, y_valid, fname_train, fname_valid = train_test_split(
    X, y, image_files, test_size=0.2, random_state=42)

# %%
im_width = X.shape[2]
im_height = X.shape[1]

im_width, im_height
# Out:
# (320, 240)

# %%
from keras.layers import Conv2D, MaxPool2D, Flatten, GlobalAvgPool2D, GlobalMaxPool2D, Dense
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
import tensorflow as tf

# %%
model = Sequential()

# CNN network
model.add( Conv2D(16, 3, activation='relu', padding='same', input_shape=(im_height, im_width, 3)) )
model.add( MaxPool2D(2) )

model.add( Conv2D(32, 3, activation='relu', padding='same') )
model.add( MaxPool2D(2) )

model.add( Conv2D(64, 3, activation='relu', padding='same') )
model.add( MaxPool2D(2) )

model.add( Conv2D(128, 3, activation='relu', padding='same') )
model.add( MaxPool2D(2) )

model.add( Conv2D(256, 3, activation='relu', padding='same') )

# Transition between CNN and MLP
model.add( GlobalAvgPool2D() )

# MLP network
model.add( Dense(256, activation='relu') )
#output layer
model.add( Dense(5,kernel_regularizer=tf.keras.regularizers.l2(0.01), activation='softmax') )

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_30 (Conv2D)           (None, 240, 320, 16)      448
# _________________________________________________________________
# max_pooling2d_24 (MaxPooling (None, 120, 160, 16)      0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 120, 160, 32)      4640
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 60, 80, 32)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 60, 80, 64)        18496
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 30, 40, 64)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 30, 40, 128)       73856
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 15, 20, 128)       0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 15, 20, 256)       295168
# _________________________________________________________________
# global_average_pooling2d_6 ( (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               65792
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 459,685
# Trainable params: 459,685
# Non-trainable params: 0
# _________________________________________________________________

# %%
optim = Adam(lr=1e-3)
model.compile(optim, 'sparse_categorical_crossentropy', metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
callbacks = [
    ReduceLROnPlateau(patience=5, factor=0.1, verbose=True),
    ModelCheckpoint('best.model', save_best_only=True),
    EarlyStopping(patience=12)
]

history = model.fit(X_train, y_train, epochs=30, validation_data=(X_valid, y_valid), batch_size=32,
                   callbacks=callbacks)
# Out:
# Epoch 1/30
# 29/29 [==============================] - 91s 3s/step - loss: 1.1963 - acc: 0.4652 - val_loss: 0.7764 - val_acc: 0.5152
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 2/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.7885 - acc: 0.4829 - val_loss: 0.7424 - val_acc: 0.5152
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 3/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.7354 - acc: 0.5375 - val_loss: 0.7293 - val_acc: 0.5152
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 4/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.7395 - acc: 0.5237 - val_loss: 0.7454 - val_acc: 0.4848
# Epoch 5/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.7379 - acc: 0.4648 - val_loss: 0.7281 - val_acc: 0.5152
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 6/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.7248 - acc: 0.4918 - val_loss: 0.7114 - val_acc: 0.5238
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 7/30
# 29/29 [==============================] - 84s 3s/step - loss: 0.7181 - acc: 0.4733 - val_loss: 0.6991 - val_acc: 0.5152
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 8/30
# 29/29 [==============================] - 92s 3s/step - loss: 0.6957 - acc: 0.5980 - val_loss: 0.6598 - val_acc: 0.5152
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 9/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.6203 - acc: 0.7223 - val_loss: 0.5049 - val_acc: 0.7576
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 10/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.5398 - acc: 0.7833 - val_loss: 0.5803 - val_acc: 0.6320
# Epoch 11/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.5180 - acc: 0.8169 - val_loss: 0.3295 - val_acc: 0.8745
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 12/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.4140 - acc: 0.8698 - val_loss: 0.3137 - val_acc: 0.8745
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 13/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.3159 - acc: 0.8967 - val_loss: 0.3121 - val_acc: 0.8961
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 14/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.2582 - acc: 0.9123 - val_loss: 0.2640 - val_acc: 0.9134
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 15/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.2264 - acc: 0.9166 - val_loss: 0.1544 - val_acc: 0.9351
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 16/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.2930 - acc: 0.8834 - val_loss: 0.1469 - val_acc: 0.9610
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 17/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.2596 - acc: 0.9348 - val_loss: 0.3260 - val_acc: 0.8615
# Epoch 18/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.2582 - acc: 0.9149 - val_loss: 0.1751 - val_acc: 0.9394
# Epoch 19/30
# 29/29 [==============================] - 86s 3s/step - loss: 0.1733 - acc: 0.9617 - val_loss: 0.1084 - val_acc: 0.9697
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 20/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.1225 - acc: 0.9644 - val_loss: 0.0840 - val_acc: 0.9784
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 21/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.1391 - acc: 0.9589 - val_loss: 0.1058 - val_acc: 0.9610
# Epoch 22/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.0901 - acc: 0.9737 - val_loss: 0.0713 - val_acc: 0.9827
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 23/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.0622 - acc: 0.9899 - val_loss: 0.0658 - val_acc: 0.9827
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 24/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.0724 - acc: 0.9762 - val_loss: 0.0707 - val_acc: 0.9740
# Epoch 25/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.0589 - acc: 0.9874 - val_loss: 0.1038 - val_acc: 0.9654
# Epoch 26/30
# 29/29 [==============================] - 84s 3s/step - loss: 0.0817 - acc: 0.9759 - val_loss: 0.2308 - val_acc: 0.9177
# Epoch 27/30
# 29/29 [==============================] - 85s 3s/step - loss: 0.0792 - acc: 0.9715 - val_loss: 0.0633 - val_acc: 0.9784
# INFO:tensorflow:Assets written to: best.model/assets
# Epoch 28/30
# 29/29 [==============================] - 84s 3s/step - loss: 0.0471 - acc: 0.9887 - val_loss: 0.1034 - val_acc: 0.9740
# Epoch 29/30
# 29/29 [==============================] - 84s 3s/step - loss: 0.0636 - acc: 0.9890 - val_loss: 0.0845 - val_acc: 0.9740
# Epoch 30/30
# 29/29 [==============================] - 84s 3s/step - loss: 0.0731 - acc: 0.9779 - val_loss: 0.0468 - val_acc: 0.9827
# INFO:tensorflow:Assets written to: best.model/assets

# %%
df_history = pd.DataFrame(history.history)

# %%
ax = df_history[['acc', 'val_acc']].plot()
ax.set_ylim(0.9, 1)
# Out:
# (0.9, 1.0)

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 8/8 [==============================] - 6s 707ms/step - loss: 0.0468 - acc: 0.9827
# [0.04675193503499031, 0.9826839566230774]

# %%
y_pred = model.predict(X_valid)

# %%
i = 55
plt.figure(figsize=(10, 10))
im = Image.open(fname_valid[i])
plt.imshow(np.uint8(im), interpolation='bilinear')
plt.title('Class: {}, Predicted: {}'.format(ids_coins[y_valid[i]], ids_coins[np.argmax(y_pred[i])]));
